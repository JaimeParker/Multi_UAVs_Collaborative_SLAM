# %%
# import libraries
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

# load data
trajectory0 = np.loadtxt('data/trajectory/KF_GBA_0.csv')
trajectory1 = np.loadtxt('data/trajectory/KF_GBA_1.csv')
ground_truth0 = np.loadtxt('data/ground_truth/GroundTruth0.tum')
ground_truth1 = np.loadtxt('data/ground_truth/GroundTruth1.tum')

# transfer data
gt0_x = ground_truth0[:, 1];
gt0_y = ground_truth0[:, 2];
gt0_z = ground_truth0[:, 3];

tra0_x = trajectory0[:, 1];
tra0_y = trajectory0[:, 2];
tra0_z = trajectory0[:, 3];

# create a figure
fig = plt.figure()
ax = fig.gca(projection = '3d')

# set info
ax.set_title("ground truth0")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")

# draw
figure = ax.plot(gt0_x, gt0_y, gt0_z, c = 'b')
fighre1 = ax.plot(tra0_x, tra0_y, tra0_z, c = 'r')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
trajectory0.size
# Out:
# 1992

# %%
ground_truth0.size
# Out:
# 582112

# %%
trajectory0.shape
# Out:
# (249, 8)
